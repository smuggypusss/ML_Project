# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_boston

# %%
boston=load_boston()

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(boston.data)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
print(boston['target'])
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
df=pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df['Price']=boston.target

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
##eda
##correlation
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.scatter(df['RM'],df['Price'])
plt.xlabel("RM")
plt.ylabel("Price")
#LR line
sns.regplot(x='RM',y="Price",data=df)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='Price'>

# %%
plt.scatter(df['LSTAT'],df['Price'])
plt.xlabel("RM")
plt.ylabel("Price")
#LR line
sns.regplot(x='LSTAT',y="Price",data=df)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='Price'>

# %%
#Dependent and independent features
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
y#Target
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: Price, Length: 506, dtype: float64

# %%
#train test split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=5)

# %%
x_train
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE      DIS   RAD    TAX  \
# 238  0.08244  30.0   4.93   0.0  0.428  6.481   18.5   6.1899   6.0  300.0
# 383  7.99248   0.0  18.10   0.0  0.700  5.520  100.0   1.5331  24.0  666.0
# 237  0.51183   0.0   6.20   0.0  0.507  7.358   71.6   4.1480   8.0  307.0
# 285  0.01096  55.0   2.25   0.0  0.389  6.453   31.9   7.3073   1.0  300.0
# 396  5.87205   0.0  18.10   0.0  0.693  6.405   96.0   1.6768  24.0  666.0
# ..       ...   ...    ...   ...    ...    ...    ...      ...   ...    ...
# 486  5.69175   0.0  18.10   0.0  0.583  6.114   79.8   3.5459  24.0  666.0
# 189  0.08370  45.0   3.44   0.0  0.437  7.185   38.9   4.5667   5.0  398.0
# 495  0.17899   0.0   9.69   0.0  0.585  5.670   28.8   2.7986   6.0  391.0
# 206  0.22969   0.0  10.59   0.0  0.489  6.326   52.5   4.3549   4.0  277.0
# 355  0.10659  80.0   1.91   0.0  0.413  5.936   19.5  10.5857   4.0  334.0
#
#      PTRATIO       B  LSTAT
# 238     16.6  379.41   6.36
# ...

# %%
y_train
# Out:
# 238    23.7
# 383    12.3
# 237    31.5
# 285    22.0
# 396    12.5
#        ...
# 486    19.1
# 189    34.9
# 495    23.1
# 206    24.4
# 355    20.6
# Name: Price, Length: 303, dtype: float64

# %%
#Standardizing the dataset,Why?
#because we use gradient descent, to reach the global minima we need to make sure that all variables have the same scale 
#to make sure that the convergence is happening quickly
from sklearn.preprocessing import StandardScaler

# %%
#Data standardization is the process of rescaling the attributes so that they have mean as 0 and variance as 1.
scaler=StandardScaler()

# %%
#The fit method is calculating the mean and variance of each of the features present in our data. 
#The transform method is transforming all the features using the respective mean and variance.
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
x_train
# Out:
# array([[-0.40895477,  0.78795056, -0.89957417, ..., -0.88501281,
#          0.23044459, -0.87462541],
#        [ 0.49519717, -0.50549786,  1.06900311, ...,  0.77712902,
#          0.42626818,  1.65954436],
#        [-0.35987362, -0.50549786, -0.70974174, ..., -0.51564796,
#          0.34979733, -1.10158677],
#        ...,
#        [-0.39791868, -0.50549786, -0.18807623, ...,  0.31542295,
#          0.38584947,  0.69043328],
#        [-0.39212345, -0.50549786, -0.05354931, ...,  0.03839932,
#          0.40353965, -0.23272856],
#        [-0.40619432,  2.94369793, -1.35098673, ...,  1.60819993,
#          0.192713  , -0.98462509]])

# %%
x_test
# Out:
# array([[-0.37469776, -0.50549786, -0.70974174, ..., -0.51564796,
#          0.31967924, -1.32437093],
#        [-0.41424592,  2.94369793, -0.89658469, ...,  0.31542295,
#          0.42626818, -1.10576397],
#        [-0.413024  , -0.50549786, -1.1267752 , ..., -0.33096554,
#          0.37342156, -0.53348717],
#        ...,
#        [-0.41137459,  1.21910004, -0.67835213, ..., -0.42330675,
#          0.38764088, -1.18095363],
#        [ 0.75129834, -0.50549786,  1.06900311, ...,  0.77712902,
#          0.23369152,  0.75030652],
#        [-0.41211528,  0.9172954 , -1.31062866, ..., -0.0539419 ,
#          0.38663321, -0.51677836]])

# %%
#Now doing linear regression
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Print the coefficients and the interepts
print(regression.coef_)
# Out:
# [-1.32348424  0.65612462 -0.42097166  0.18946961 -1.59738024  3.23873004
#  -0.45804158 -2.62621964  2.47386754 -1.84967268 -2.1655412   1.07963121
#  -2.65337977]

# %%
print(regression.intercept_)
# Out:
# 22.50363036303636

# %%
#On which parameters the regression has been trained
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
#Prediction with test 
reg_pred=regression.predict(x_test)

# %%
#Plot scatter for the prediction
plt.scatter(y_test,reg_pred)
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
error=y_test-reg_pred
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
error
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
#plot the residuals
sns.displot(error,kind="kde")
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
#plot between prediction and error
plt.scatter(reg_pred,error)
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# R square and adjusted R square
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
score
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
#adjusted R square
1 - (1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
#Pickling the model for deployement 
import pickle
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
pickle.dump(regression,open('regression.pkl','wb'))
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
pickled_model=pickle.load(open('regression.pkl','rb'))
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
#Reshaping the dataset is often necessary to ensure that the data is in the correct format or structure for training and using machine learning models effectively. 
#Reshaping allows you to organize the data in a way that matches the input requirements of the specific model you are using. 

pickled_model.predict(scaler.transform(boston.data[0].reshape(1,-1)))
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'c:\Users\Asus\AppData\Local\Programs\Python\Python37\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'
